# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

chile_2018 = pd.read_csv('/content/Chile2018_filtrado.csv')
brasil_2018 = pd.read_csv('/content/Brasil2018_filtrado.csv')
argentina_2017 = pd.read_csv('/content/Argentina2017_filtrado.csv')
colombia_2005_2006 = pd.read_csv('/content/Colombia05-06_filtrado.csv')
chile_2006 = pd.read_csv('/content/chile2006_filtrado.csv')
uruguay_2006 = pd.read_csv('/content/Uruguay2006_filtrado.csv')
peru_2006 = pd.read_csv('/content/Peru2006_filtrado.csv')
brasil_2006 = pd.read_csv('/content/Brasil2006_filtrado.csv')
peru_2012 = pd.read_csv('/content/Peru2012_filtrado.csv')
mexico_2012 = pd.read_csv('/content/Mexico2012_filtrado.csv')
peru_2018 = pd.read_csv('/content/Peru2018_filtrado.csv')
ecuador_2018 = pd.read_csv('/content/Ecuador2018_filtrado.csv')
colombia_2018 = pd.read_csv('/content/Colombia2018_filtrado.csv')
ecuador_2013 = pd.read_csv('/content/Ecuador2013_filtrado.csv')
colombia_2012 = pd.read_csv('/content/Colombia2012_filtrado.csv')
chile_2012 = pd.read_csv('/content/Chile2012_filtrado.csv')
brasil_2014 = pd.read_csv('/content/Brasil2014_filtrado.csv')
argentina_2012_2013 = pd.read_csv('/content/Arg1213_filtrado.csv')

chile_2018['pais'] = 'Chile'
chile_2018['anio'] = 2018
brasil_2018['pais'] = 'Brasil'
brasil_2018['anio'] = 2018
argentina_2017['pais'] = 'Argentina'
argentina_2017['anio'] = 2017
colombia_2005_2006['pais'] = 'Colombia'
colombia_2005_2006['anio'] = 2006
chile_2006['pais'] = 'Chile'
chile_2006['anio'] = 2006
uruguay_2006['pais'] = 'Uruguay'
uruguay_2006['anio'] = 2006
peru_2006['pais'] = 'Peru'
peru_2006['anio'] = 2006
brasil_2006['pais'] = 'Brasil'
brasil_2006['anio'] = 2006
peru_2012['pais'] = 'Peru'
peru_2012['anio'] = 2012
mexico_2012['pais'] = 'Mexico'
mexico_2012['anio'] = 2012
peru_2018['pais'] = 'Peru'
peru_2018['anio'] = 2018
ecuador_2018['pais'] = 'Ecuador'
ecuador_2018['anio'] = 2018
colombia_2018['pais'] = 'Colombia'
colombia_2018['anio'] = 2018
ecuador_2013['pais'] = 'Ecuador'
ecuador_2013['anio'] = 2013
colombia_2012['pais'] = 'Colombia'
colombia_2012['anio'] = 2012
chile_2012['pais'] = 'Chile'
chile_2012['anio'] = 2012
brasil_2014['pais'] = 'Brasil'
brasil_2014['anio'] = 2014
argentina_2012_2013['pais'] = 'Argentina'
argentina_2012_2013['anio'] = 2013

df = pd.concat([chile_2018, brasil_2018, argentina_2017, colombia_2005_2006, chile_2006, uruguay_2006, peru_2006, brasil_2006, peru_2012, mexico_2012, peru_2018, ecuador_2018, colombia_2018, ecuador_2013, colombia_2012, chile_2012, brasil_2014, argentina_2012_2013], ignore_index=True)

# %%
import seaborn as sns

sns.set(style="whitegrid")

beta_df = betas.reset_index()
beta_df.columns = ['Period', 'Beta Coefficient']

beta_df['Period'] = beta_df['Period'].replace({'period_1': '2005-2006', 'period_2': '2012-2014', 'period_3': '2018'})

plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Period', y='Beta Coefficient', data=beta_df, palette='viridis', edgecolor='black')

for i in range(len(beta_df)):
    ax.text(i, beta_df['Beta Coefficient'][i] + 0.02 if beta_df['Beta Coefficient'][i] >= 0 else beta_df['Beta Coefficient'][i] - 0.05,
            f"{beta_df['Beta Coefficient'][i]:.2f}", ha='center', fontsize=12, color='black')

plt.title('Beta Coefficients of Periods', fontsize=16)
plt.xlabel('Period', fontsize=14)
plt.ylabel('Beta Coefficient', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-79-7b31f8dd1689>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Period', y='Beta Coefficient', data=beta_df, palette='viridis', edgecolor='black')

# %%
logit_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             Logit Regression Results
# ...
# Dep. Variable:     Satisfaction_binary   No. Observations:                  100
# Model:                           Logit   Df Residuals:                       90
# Method:                            MLE   Df Model:                            9
# Date:                 Sun, 02 Jun 2024   Pseudo R-squ.:                 0.04417
# Time:                         11:19:53   Log-Likelihood:                -65.563
# converged:                       False   LL-Null:                       -68.593
# Covariance Type:             nonrobust   LLR p-value:                    0.7339
# ...
#                                                                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
print(model_period1.summary().tables[1])
print(model_period2.summary().tables[1])
print(model_period3.summary().tables[1])
# Out:
# ...
#                                                                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                0.8281      3.512      0.236      0.814      -6.056       7.712
# Important in life: Friends                                                           0.1634      0.373      0.438      0.662      -0.568       0.895
# Most people can be trusted                                                           0.3640      0.346      1.051      0.293      -0.315       1.043
# Schwartz: It is important to this person to be rich                                 -0.2989      0.355     -0.842      0.400      -0.994       0.396
# ...
